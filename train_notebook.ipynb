# %% [markdown]
# # Get license plate dataset

# %%
# !curl -L "https://universe.roboflow.com/ds/kdXoju18dM?key=7X5PeoFIWk" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#  extracting: train/xemay2040_jpg.rf.aab87edfce96e94eb21fda59097c1680.jpg
#  extracting: train/xemay2040_jpg.rf.f5715421bfb25ae3e3b3d20a72226064.jpg
#  extracting: train/xemay2041_jpg.rf.48933e36147e932feda2879c1fb39e95.jpg
#  extracting: train/xemay2041_jpg.rf.563e0fe10bd74e45aa02a7063e385513.jpg
#  extracting: train/xemay2041_jpg.rf.da93b949c97478ca5c3f3da82b98afca.jpg
#  extracting: train/xemay2047_jpg.rf.12bc3c6e45e8871fe522f7bdced0e2b3.jpg
#  extracting: train/xemay2047_jpg.rf.3f33fb2afdc0e15dd4f2b310ca62bc03.jpg
#  extracting: train/xemay2047_jpg.rf.468c278fb0b03d40bf0c2c2fe2b75631.jpg
#  extracting: train/xemay2048_jpg.rf.675d6a373e117f75c89281bc40f758be.jpg
#  extracting: train/xemay2048_jpg.rf.98feb087e3b03b296bc62267368fba61.jpg
#  extracting: train/xemay2048_jpg.rf.d6b163cc200b8041695dc258fa340d6b.jpg
#  extracting: train/xemay2049_jpg.rf.79f7feab13ddb732fecea2624ef3d651.jpg
#  extracting: train/xemay2049_jpg.rf.cedbfd0da3aeb7c1c354e9ee5ec92de5.jpg
#  extracting: train/xemay2049_jpg.rf.e45bbb804ea632e15253f8f9f1cf69a0.jpg
#  extracting: train/xemay204_jpg.rf.407138972f437985a572de5caa04aff7.jpg
#  extracting: train/xemay204_jpg.rf.5a2996588a42e768bb1880f8a842b6ca.jpg
#  extracting: train/xemay204_jpg.rf.c158d92ac8dcf9212deb9ca095a2e275.jpg
#  extracting: train/xemay2050_jpg.rf.347deb358d36e0d05f0e5e572d16b979.jpg
#  extracting: train/xemay2050_jpg.rf.c586eed4e7c6cedf06bad42b46f675fd.jpg
#  extracting: train/xemay2050_jpg.rf.fe3c1ff1e147608171bc1a3f4296eedc.jpg
#  extracting: train/xemay2052_jpg.rf.5c0b5e869677cde93ad42a5ee3fa00af.jpg
#  extracting: train/xemay2052_jpg.rf.92654e3d08a352c53e0e177341ecb7b3.jpg
#  extracting: train/xemay2052_jpg.rf.c6083a792387214997ddaae2fb6680db.jpg
#  extracting: train/xemay2053_jpg.rf.0a2c13d3a18bf4df34faa2f745f0745d.jpg
#  extracting: train/xemay2053_jpg.rf.2ae7331e764d5d5fe4b326ac56ca4984.jpg
#  extracting: train/xemay2053_jpg.rf.ac84f500ce6f71d571aed0ad737c52f6.jpg
#  extracting: train/xemay2054_jpg.rf.2da196bca8d8d71231672b6fabc7c670.jpg
#  extracting: train/xemay2054_jpg.rf.6b3a203026123dd8dd327cb95a6c976e.jpg
#  extracting: train/xemay2054_jpg.rf.d8b3f8ce6eec0fe39735cd24a17fdbde.jpg
#  extracting: train/xemay2055_jpg.rf.25e9b2bde65358bf85085f69c78fb943.jpg
#  extracting: valid/xemayBigPlate37_jpg.rf.5e8cdc757bda97fabe41315222edc0a1.jpg
#  extracting: valid/xemayBigPlate45_jpg.rf.46033b1e3fb36624fa047a4ed0f4706c.jpg
#  extracting: valid/xemayBigPlate46_jpg.rf.a69b901a542fa8783da5cf27060db47a.jpg
#  extracting: valid/xemayBigPlate51_jpg.rf.c7a495a7f04a098db67bb7323a9b2cf1.jpg
#  extracting: valid/xemayBigPlate57_jpg.rf.c4e68cbea7ecac08b7a3bc7fe134e472.jpg
#  extracting: valid/xemayBigPlate60_jpg.rf.9ae64dffbbab8ec8e3438684166fb832.jpg
#  extracting: valid/xemayBigPlate61_jpg.rf.e85696758da3a875fe9e5b86fc8b863d.jpg
#  extracting: valid/xemayBigPlate69_jpg.rf.2f735c9dccbee08f8d95873b5434a177.jpg
#  extracting: valid/xemayBigPlate70_jpg.rf.357d9243cd45d3ca2385170688a5321b.jpg
#  extracting: valid/xemayBigPlate77_jpg.rf.eb9d53f5b27440fdb845a9f8d6f2cc5a.jpg
#  extracting: valid/xemayBigPlate78_jpg.rf.7e081a4244b3473be4e9fc62cca9ebc1.jpg
#  extracting: valid/xemayBigPlate86_jpg.rf.d98e70fabc215ed2a54006916dc4e7cb.jpg
#  extracting: valid/xemayBigPlate87_jpg.rf.9539228e6e8772a39d82b4b9f5cfc658.jpg
#  extracting: valid/xemayBigPlate89_jpg.rf.6045cc081d9458be3ea2bdb38674915f.jpg
#  extracting: valid/xemayBigPlate93_jpg.rf.c57554b510b615d1f20cefbc5062c90e.jpg

# %%
# !mkdir license_plate_data; mv train ./license_plate_data/train; mv test ./license_plate_data/test; mv valid ./license_plate_data/valid;

# %% [markdown]
# Create models directory for keeping the best model so far

# %%
# !mkdir models
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %% [markdown]
# # DATASET CLASS

# %%
from torch.utils.data import Dataset
from torchvision.io.image import read_image
import json
import cv2
import numpy as np
import torch
class LicensePlateDataset(Dataset):

  def __init__(self,  mode,annotation_path):
    self.base_path = f"{annotation_path}/{mode}/"
    f = open(self.base_path+"_annotations.coco.json")
    data = json.load(f)
    self.images = data["images"]
    self.annotations = data["annotations"]

  def __len__(self):

    return len(self.images)

  def __getitem__(self, idx):

    input_idx = self.annotations[idx]["image_id"]
    input, label = self.get_input(input_idx)
    output = np.array([label, *self.get_output(idx)]).astype(np.float32).reshape(1,-1)
    return input, str({
        "labels": [label],
        "boxes": [self.get_output(idx)]
    })

  def get_input(self, idx):

    img_path = self.base_path + self.images[idx]["file_name"]
    img = read_image(img_path)

    label = self.images[idx]["license"]

    return img, label


  def get_output(self, idx):
    box_corrs = self.annotations[idx]["bbox"]
    return [box_corrs[0], box_corrs[1], box_corrs[0]+box_corrs[2], box_corrs[1]+box_corrs[3]]

# %% [markdown]
# # Utils

# %%
from typing import Tuple, List, Dict, Optional
import torch
from torch import Tensor
from collections import OrderedDict
from torchvision.models.detection.roi_heads import fastrcnn_loss
from torchvision.models.detection.rpn import concat_box_prediction_layers
def eval_forward(model, images, targets):
    """
    Args:
        images (list[Tensor]): images to be processed
        targets (list[Dict[str, Tensor]]): ground-truth boxes present in the image (optional)
    Returns:
        result (list[BoxList] or dict[Tensor]): the output from the model.
            It returns list[BoxList] contains additional fields
            like `scores`, `labels` and `mask` (for Mask R-CNN models).
    """
    model.eval()

    original_image_sizes: List[Tuple[int, int]] = []
    for img in images:
        val = img.shape[-2:]
        assert len(val) == 2
        original_image_sizes.append((val[0], val[1]))

    images, targets = model.transform(images, targets)

    # Check for degenerate boxes
    if targets is not None:
        for target_idx, target in enumerate(targets):
            boxes = target["boxes"]
            degenerate_boxes = boxes[:, 2:] <= boxes[:, :2]
            if degenerate_boxes.any():
                # print the first degenerate box
                bb_idx = torch.where(degenerate_boxes.any(dim=1))[0][0]
                degen_bb: List[float] = boxes[bb_idx].tolist()
                raise ValueError(
                    "All bounding boxes should have positive height and width."
                    f" Found invalid box {degen_bb} for target at index {target_idx}."
                )

    features = model.backbone(images.tensors)
    if isinstance(features, torch.Tensor):
        features = OrderedDict([("0", features)])
    model.rpn.training=True


    features_rpn = list(features.values())
    objectness, pred_bbox_deltas = model.rpn.head(features_rpn)
    anchors = model.rpn.anchor_generator(images, features_rpn)

    num_images = len(anchors)
    num_anchors_per_level_shape_tensors = [o[0].shape for o in objectness]
    num_anchors_per_level = [s[0] * s[1] * s[2] for s in num_anchors_per_level_shape_tensors]
    objectness, pred_bbox_deltas = concat_box_prediction_layers(objectness, pred_bbox_deltas)

    # apply pred_bbox_deltas to anchors to obtain the decoded proposals
    # the proposals
    proposals = model.rpn.box_coder.decode(pred_bbox_deltas.detach(), anchors)
    proposals = proposals.view(num_images, -1, 4)
    proposals, scores = model.rpn.filter_proposals(proposals, objectness, images.image_sizes, num_anchors_per_level)

    proposal_losses = {}
    assert targets is not None
    labels, matched_gt_boxes = model.rpn.assign_targets_to_anchors(anchors, targets)
    regression_targets = model.rpn.box_coder.encode(matched_gt_boxes, anchors)
    loss_objectness, loss_rpn_box_reg = model.rpn.compute_loss(
        objectness, pred_bbox_deltas, labels, regression_targets
    )
    proposal_losses = {
        "loss_objectness": loss_objectness,
        "loss_rpn_box_reg": loss_rpn_box_reg,
    }

    image_shapes = images.image_sizes
    proposals, matched_idxs, labels, regression_targets = model.roi_heads.select_training_samples(proposals, targets)
    box_features = model.roi_heads.box_roi_pool(features, proposals, image_shapes)
    box_features = model.roi_heads.box_head(box_features)
    class_logits, box_regression = model.roi_heads.box_predictor(box_features)

    result: List[Dict[str, torch.Tensor]] = []
    detector_losses = {}
    loss_classifier, loss_box_reg = fastrcnn_loss(class_logits, box_regression, labels, regression_targets)
    detector_losses = {"loss_classifier": loss_classifier, "loss_box_reg": loss_box_reg}
    boxes, scores, labels = model.roi_heads.postprocess_detections(class_logits, box_regression, proposals, image_shapes)
    num_images = len(boxes)
    for i in range(num_images):
        result.append(
            {
                "boxes": boxes[i],
                "labels": labels[i],
                "scores": scores[i],
            }
        )
    detections = result
    detections = model.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
    model.rpn.training=False
    model.roi_heads.training=False
    losses = {}
    losses.update(detector_losses)
    losses.update(proposal_losses)
    return losses, detections

# %%
import ast

def train(n_steps, model, optimizer, device, epoch, train_loader, preprocess, batch_size):
  model.train()
  losses_l = []

  for stp, batch in enumerate(train_loader):
    optimizer.zero_grad()

    images = list(preprocess(image).to(device) for image in batch[0])
    targets = [ast.literal_eval(target) for target in batch[1]]
    targets = [{k: torch.tensor(v).to(device) for k,v in target.items()} for target in targets]

    losses = model(images, targets)
    loss = sum(loss for loss in losses.values())
    losses_l.append(loss.item())
    loss.backward()
    optimizer.step()
    print('train | epoch = {}, iter = [{}|{}], loss = {}, loss_box = {}'.format(epoch, stp, n_steps,
                                                                                round(loss.item(), 6),
                                                                                round(losses['loss_box_reg'].item(), 6)))
    if stp > n_steps:
      break

  return np.mean(losses_l)



def validate(n_steps, model, optimizer, device, epoch, val_loader, preprocess, batch_size):
  losses_l = []
  for stp, batch in enumerate(val_loader):
    images = list(preprocess(image).to(device) for image in batch[0])
    targets = [ast.literal_eval(target) for target in batch[1]]
    targets = [{k: torch.tensor(v).to(device) for k,v in target.items()} for target in targets]

    losses, detections = eval_forward(model, images,targets)
    loss = sum(loss for loss in losses.values())
    losses_l.append(loss.item())

    print('val | epoch = {}, iter = [{}|{}], loss = {},  loss_box = {}'.format(epoch, stp, n_steps,
                                                                                round(loss.item(), 6),
                                                                                round(losses['loss_box_reg'].item(), 6)))

  return np.mean(losses_l)

# %% [markdown]
# # CONFIG

# %%
BATCH_SIZE = 16
NUM_EPOCHS = 500

STEPS_PER_EPOCH = 200
device = 'cuda'

LEARNING_RATE = 0.005
MOMENTUM = 0.9
WEIGHT_DECAY = 0.0005

EXPORT_PATH = "./models/best_model.pt"
last_best = None

# %% [markdown]
# # TRAINING

# %%
import torch
from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2,FasterRCNN_ResNet50_FPN_V2_Weights
from torchvision.utils import draw_bounding_boxes
from torchvision.transforms.functional import to_pil_image
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import ast
weights = FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT

preprocess = weights.transforms()


train_dataset = LicensePlateDataset("train", "./license_plate_data")
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=True
    )



val_dataset = LicensePlateDataset("valid", "./license_plate_data")
val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=True
    )




model = fasterrcnn_resnet50_fpn_v2(weights=weights, box_score_thresh=0.7)

# disable gradient flow
for layer in model.parameters():
  layer.requires_grad = False

# create new predicting layer that will be trained
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 2)
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)


for epoch in range(NUM_EPOCHS):
  train_loss = train(STEPS_PER_EPOCH, model, optimizer, device, epoch, train_loader, preprocess, BATCH_SIZE)
  val_loss = validate(STEPS_PER_EPOCH, model, optimizer, device, epoch, val_loader, preprocess, BATCH_SIZE)
  lr_scheduler.step()
  print("TRAIN LOSS: {}, VALIDATION LOSS: {}".format(train_loss.item(), val_loss.item()))
  if last_best is None or last_best > val_loss.item():
    last_best = val_loss.item()
    torch.save(model, EXPORT_PATH)
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# train | epoch = 14, iter = [178|200], loss = 0.143994, loss_box = 0.020067
# train | epoch = 14, iter = [179|200], loss = 0.09333, loss_box = 0.012361
# train | epoch = 14, iter = [180|200], loss = 0.111669, loss_box = 0.018332
# train | epoch = 14, iter = [181|200], loss = 0.151364, loss_box = 0.011737
# train | epoch = 14, iter = [182|200], loss = 0.157224, loss_box = 0.017336
# train | epoch = 14, iter = [183|200], loss = 0.140156, loss_box = 0.021789
# train | epoch = 14, iter = [184|200], loss = 0.095665, loss_box = 0.020971
# train | epoch = 14, iter = [185|200], loss = 0.120472, loss_box = 0.026087
# train | epoch = 14, iter = [186|200], loss = 0.108458, loss_box = 0.013063
# train | epoch = 14, iter = [187|200], loss = 0.135512, loss_box = 0.01585
# train | epoch = 14, iter = [188|200], loss = 0.11107, loss_box = 0.006705
# train | epoch = 14, iter = [189|200], loss = 0.120106, loss_box = 0.017903
# train | epoch = 14, iter = [190|200], loss = 0.12916, loss_box = 0.020194
# train | epoch = 14, iter = [191|200], loss = 0.11087, loss_box = 0.018473
# train | epoch = 14, iter = [192|200], loss = 0.115124, loss_box = 0.013765
# train | epoch = 14, iter = [193|200], loss = 0.100887, loss_box = 0.019209
# train | epoch = 14, iter = [194|200], loss = 0.124471, loss_box = 0.018952
# train | epoch = 14, iter = [195|200], loss = 0.181181, loss_box = 0.014647
# train | epoch = 14, iter = [196|200], loss = 0.101157, loss_box = 0.021879
# train | epoch = 14, iter = [197|200], loss = 0.111853, loss_box = 0.014209
# train | epoch = 14, iter = [198|200], loss = 0.124654, loss_box = 0.013438
# train | epoch = 14, iter = [199|200], loss = 0.122444, loss_box = 0.016716
# train | epoch = 14, iter = [200|200], loss = 0.128037, loss_box = 0.019498
# train | epoch = 14, iter = [201|200], loss = 0.087869, loss_box = 0.016131
# [{'boxes': tensor([[214.9709, 154.8916, 298.4499, 268.7817]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8266], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[164.5113, 182.0362, 250.5398, 293.5587]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9411], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[178.0808, 117.9701, 254.6126, 151.7915]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8213], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[224.7238,  72.1713, 303.0743, 186.3951]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9162], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[150.8141, 171.1126, 248.9750, 223.9198]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8160], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[239.7184, 245.3158, 321.8390, 292.9365]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8744], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[189.4846, 271.1425, 263.3386, 299.6824]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8270], device='cuda:0', grad_fn=<IndexBackward0>)}]
# val | epoch = 14, iter = [0|200], loss = 0.154384,  loss_box = 0.016019
# [{'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[223.0218,  87.9998, 253.9350, 125.5015]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8599], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[246.5901, 304.4543, 314.6437, 337.8829]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8946], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[125.5798, 150.0515, 188.0946, 232.6195]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9976], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}]
# val | epoch = 14, iter = [1|200], loss = 0.28045,  loss_box = 0.004416
# [{'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[198.0654,  47.1491, 272.6217, 137.1345]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.
], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9646], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[126.6876, 209.8174, 271.7044, 344.9465]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9953], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[206.8512, 213.9151, 286.2434, 265.0630]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7662], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[173.2047, 134.0564, 261.6259, 240.8335]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9552], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[163.6514, 154.4234, 240.7733, 255.5759]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9259], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[161.6469, 154.8481, 238.8652, 255.3195]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7146], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[101.5183, 324.7104, 194.1069, 366.8631]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.7171], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[228.2426, 346.1865, 304.3200, 377.5375]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.8810], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[195.6044, 129.7246, 244.4640, 185.6274]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9632], device='cuda:0', grad_fn=<IndexBackward0>)}]
# val | epoch = 14, iter = [12|200], loss = 0.123363,  loss_box = 0.016922
# [{'boxes': tensor([], device='cuda:0', size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0', grad_fn=<IndexBackward0>)}, {'boxes': tensor([[225.1665, 203.3406, 250.6941, 227.3662]], device='cuda:0',
# ...
# train | epoch = 18, iter = [1|200], loss = 0.111904, loss_box = 0.018797
# train | epoch = 18, iter = [2|200], loss = 0.098031, loss_box = 0.017218
# train | epoch = 18, iter = [3|200], loss = 0.108771, loss_box = 0.021078
# train | epoch = 18, iter = [4|200], loss = 0.098513, loss_box = 0.013141
# train | epoch = 18, iter = [5|200], loss = 0.107163, loss_box = 0.01586
# train | epoch = 18, iter = [6|200], loss = 0.105673, loss_box = 0.014525
# train | epoch = 18, iter = [7|200], loss = 0.113874, loss_box = 0.013386
# train | epoch = 18, iter = [8|200], loss = 0.116522, loss_box = 0.019897
# train | epoch = 18, iter = [9|200], loss = 0.118876, loss_box = 0.023074
# train | epoch = 18, iter = [10|200], loss = 0.094479, loss_box = 0.016816
# train | epoch = 18, iter = [11|200], loss = 0.137026, loss_box = 0.02286
# train | epoch = 18, iter = [12|200], loss = 0.106058, loss_box = 0.016019
# train | epoch = 18, iter = [13|200], loss = 0.11614, loss_box = 0.016637
# train | epoch = 18, iter = [14|200], loss = 0.125287, loss_box = 0.013503
# train | epoch = 18, iter = [15|200], loss = 0.108434, loss_box = 0.021477
# train | epoch = 18, iter = [16|200], loss = 0.128841, loss_box = 0.021879
# train | epoch = 18, iter = [17|200], loss = 0.119632, loss_box = 0.025962
# train | epoch = 18, iter = [18|200], loss = 0.110774, loss_box = 0.021953
# train | epoch = 18, iter = [19|200], loss = 0.102133, loss_box = 0.021181
# train | epoch = 18, iter = [20|200], loss = 0.128277, loss_box = 0.01574
# train | epoch = 18, iter = [21|200], loss = 0.11398, loss_box = 0.021267
# train | epoch = 18, iter = [22|200], loss = 0.143687, loss_box = 0.021874
# train | epoch = 18, iter = [23|200], loss = 0.164655, loss_box = 0.017661
# train | epoch = 18, iter = [24|200], loss = 0.120035, loss_box = 0.022795
# train | epoch = 18, iter = [25|200], loss = 0.141467, loss_box = 0.019544
# train | epoch = 18, iter = [26|200], loss = 0.108195, loss_box = 0.016412
# train | epoch = 18, iter = [27|200], loss = 0.114888, loss_box = 0.018322
# train | epoch = 18, iter = [28|200], loss = 0.116649, loss_box = 0.016295
# train | epoch = 18, iter = [29|200], loss = 0.157637, loss_box = 0.01618
# train | epoch = 18, iter = [30|200], loss = 0.124856, loss_box = 0.013751
# train | epoch = 18, iter = [31|200], loss = 0.125824, loss_box = 0.01995
# train | epoch = 18, iter = [32|200], loss = 0.118106, loss_box = 0.032433
# train | epoch = 18, iter = [33|200], loss = 0.138248, loss_box = 0.01799
# train | epoch = 18, iter = [34|200], loss = 0.118543, loss_box = 0.018737
# train | epoch = 18, iter = [35|200], loss = 0.139494, loss_box = 0.019895
# train | epoch = 18, iter = [36|200], loss = 0.130148, loss_box = 0.013718
# train | epoch = 18, iter = [37|200], loss = 0.130316, loss_box = 0.016952
# train | epoch = 18, iter = [38|200], loss = 0.12562, loss_box = 0.016926
# train | epoch = 18, iter = [39|200], loss = 0.1816, loss_box = 0.013
# train | epoch = 18, iter = [40|200], loss = 0.107882, loss_box = 0.016873
# train | epoch = 18, iter = [41|200], loss = 0.105092, loss_box = 0.016751
# train | epoch = 18, iter = [42|200], loss = 0.132926, loss_box = 0.016816
# train | epoch = 18, iter = [43|200], loss = 0.116755, loss_box = 0.022094
# train | epoch = 18, iter = [44|200], loss = 0.132904, loss_box = 0.02437
# train | epoch = 18, iter = [45|200], loss = 0.118229, loss_box = 0.018688
# train | epoch = 18, iter = [46|200], loss = 0.118755, loss_box = 0.01307
# train | epoch = 18, iter = [47|200], loss = 0.118303, loss_box = 0.020978
# train | epoch = 18, iter = [48|200], loss = 0.131396, loss_box = 0.019357
# train | epoch = 18, iter = [49|200], loss = 0.101174, loss_box = 0.01591
# train | epoch = 18, iter = [50|200], loss = 0.114974, loss_box = 0.015523
# train | epoch = 18, iter = [51|200], loss = 0.182265, loss_box = 0.010891
# train | epoch = 18, iter = [52|200], loss = 0.095962, loss_box = 0.01777
# train | epoch = 18, iter = [53|200], loss = 0.10653, loss_box = 0.017169
# train | epoch = 18, iter = [54|200], loss = 0.127972, loss_box = 0.022162
# train | epoch = 18, iter = [55|200], loss = 0.147841, loss_box = 0.015373
# train | epoch = 18, iter = [56|200], loss = 0.126953, loss_box = 0.021694
# train | epoch = 18, iter = [57|200], loss = 0.113402, loss_box = 0.020495
# train | epoch = 18, iter = [58|200], loss = 0.116146, loss_box = 0.022924
# train | epoch = 18, iter = [59|200], loss = 0.136575, loss_box = 0.010996
# train | epoch = 18, iter = [60|200], loss = 0.117707, loss_box = 0.013737
# train | epoch = 18, iter = [61|200], loss = 0.114395, loss_box = 0.017699
# train | epoch = 18, iter = [62|200], loss = 0.120686, loss_box = 0.021431
# train | epoch = 18, iter = [63|200], loss = 0.105979, loss_box = 0.013309
# train | epoch = 18, iter = [64|200], loss = 0.197036, loss_box = 0.021069
# train | epoch = 18, iter = [65|200], loss = 0.110199, loss_box = 0.021119
# train | epoch = 18, iter = [66|200], loss = 0.115958, loss_box = 0.021412
# train | epoch = 18, iter = [67|200], loss = 0.108586, loss_box = 0.02309
# train | epoch = 18, iter = [68|200], loss = 0.162814, loss_box = 0.020067
# train | epoch = 18, iter = [69|200], loss = 0.135116, loss_box = 0.02474
# train | epoch = 18, iter = [70|200], loss = 0.133667, loss_box = 0.013725
# train | epoch = 18, iter = [71|200], loss = 0.133283, loss_box = 0.011515
# train | epoch = 18, iter = [72|200], loss = 0.111903, loss_box = 0.014923
# train | epoch = 18, iter = [73|200], loss = 0.11994, loss_box = 0.014848
# train | epoch = 18, iter = [74|200], loss = 0.171913, loss_box = 0.020598
# train | epoch = 18, iter = [75|200], loss = 0.120221, loss_box = 0.023319
# train | epoch = 18, iter = [76|200], loss = 0.146943, loss_box = 0.016895
# train | epoch = 18, iter = [77|200], loss = 0.117187, loss_box = 0.016689
# train | epoch = 18, iter = [78|200], loss = 0.146165, loss_box = 0.016835
# train | epoch = 18, iter = [79|200], loss = 0.124215, loss_box = 0.014887
# train | epoch = 18, iter = [80|200], loss = 0.137074, loss_box = 0.018456
# train | epoch = 18, iter = [81|200], loss = 0.117036, loss_box = 0.020656
# train | epoch = 18, iter = [82|200], loss = 0.143995, loss_box = 0.019653
# train | epoch = 18, iter = [83|200], loss = 0.130287, loss_box = 0.019138
# train | epoch = 18, iter = [84|200], loss = 0.117424, loss_box = 0.011941
# train | epoch = 18, iter = [85|200], loss = 0.125592, loss_box = 0.019002
# train | epoch = 18, iter = [86|200], loss = 0.127178, loss_box = 0.013649
# train | epoch = 18, iter = [87|200], loss = 0.116289, loss_box = 0.012961
# train | epoch = 18, iter = [88|200], loss = 0.139424, loss_box = 0.018428
# train | epoch = 18, iter = [89|200], loss = 0.101392, loss_box = 0.018424
# train | epoch = 18, iter = [90|200], loss = 0.136938, loss_box = 0.026054
# train | epoch = 18, iter = [91|200], loss = 0.12624, loss_box = 0.022341
# train | epoch = 18, iter = [92|200], loss = 0.111093, loss_box = 0.014988
# train | epoch = 18, iter = [93|200], loss = 0.107514, loss_box = 0.017597
# train | epoch = 18, iter = [94|200], loss = 0.120988, loss_box = 0.014377
# train | epoch = 18, iter = [95|200], loss = 0.112247, loss_box = 0.022681
# train | epoch = 18, iter = [96|200], loss = 0.119932, loss_box = 0.016201
# train | epoch = 18, iter = [97|200], loss = 0.111868, loss_box = 0.01502
# train | epoch = 18, iter = [98|200], loss = 0.121744, loss_box = 0.019637
# train | epoch = 18, iter = [99|200], loss = 0.10429, loss_box = 0.012588
# train | epoch = 18, iter = [100|200], loss = 0.10551, loss_box = 0.022747
# train | epoch = 18, iter = [101|200], loss = 0.12206, loss_box = 0.013323
# train | epoch = 18, iter = [102|200], loss = 0.128671, loss_box = 0.027293
# train | epoch = 18, iter = [103|200], loss = 0.114389, loss_box = 0.016061
# train | epoch = 18, iter = [104|200], loss = 0.112856, loss_box = 0.016976
# train | epoch = 18, iter = [105|200], loss = 0.133772, loss_box = 0.0128
# train | epoch = 18, iter = [106|200], loss = 0.131152, loss_box = 0.020957
# train | epoch = 18, iter = [107|200], loss = 0.134712, loss_box = 0.020952
# train | epoch = 18, iter = [108|200], loss = 0.139914, loss_box = 0.012783
# train | epoch = 18, iter = [109|200], loss = 0.203936, loss_box = 0.011084
# train | epoch = 18, iter = [110|200], loss = 0.137744, loss_box = 0.019194
# train | epoch = 18, iter = [111|200], loss = 0.13529, loss_box = 0.020555
# train | epoch = 18, iter = [112|200], loss = 0.147634, loss_box = 0.016932
# train | epoch = 18, iter = [113|200], loss = 0.126555, loss_box = 0.017349
# train | epoch = 18, iter = [114|200], loss = 0.121746, loss_box = 0.03013
# train | epoch = 18, iter = [115|200], loss = 0.137973, loss_box = 0.01642
# train | epoch = 18, iter = [116|200], loss = 0.121986, loss_box = 0.01406
# train | epoch = 18, iter = [117|200], loss = 0.116049, loss_box = 0.011147
# train | epoch = 18, iter = [118|200], loss = 0.126118, loss_box = 0.014634
# train | epoch = 18, iter = [119|200], loss = 0.112459, loss_box = 0.01485
# train | epoch = 18, iter = [120|200], loss = 0.119157, loss_box = 0.022839
# train | epoch = 18, iter = [121|200], loss = 0.186644, loss_box = 0.013863
# train | epoch = 18, iter = [122|200], loss = 0.112395, loss_box = 0.019816
# train | epoch = 18, iter = [123|200], loss = 0.104714, loss_box = 0.018834
# train | epoch = 18, iter = [124|200], loss = 0.117891, loss_box = 0.012845
# train | epoch = 18, iter = [125|200], loss = 0.104326, loss_box = 0.014616
# train | epoch = 18, iter = [126|200], loss = 0.14574, loss_box = 0.010318
# train | epoch = 18, iter = [127|200], loss = 0.105337, loss_box = 0.013467
# train | epoch = 18, iter = [128|200], loss = 0.102934, loss_box = 0.014181
# train | epoch = 18, iter = [129|200], loss = 0.118898, loss_box = 0.016383
# train | epoch = 18, iter = [130|200], loss = 0.112745, loss_box = 0.021421
# train | epoch = 18, iter = [131|200], loss = 0.113633, loss_box = 0.02326
# train | epoch = 18, iter = [132|200], loss = 0.115896, loss_box = 0.01623
# train | epoch = 18, iter = [133|200], loss = 0.13328, loss_box = 0.020087
# train | epoch = 18, iter = [134|200], loss = 0.1159, loss_box = 0.025652
# train | epoch = 18, iter = [135|200], loss = 0.100573, loss_box = 0.010189
# train | epoch = 18, iter = [136|200], loss = 0.151531, loss_box = 0.02646
# train | epoch = 18, iter = [137|200], loss = 0.138479, loss_box = 0.021772
# train | epoch = 18, iter = [138|200], loss = 0.17909, loss_box = 0.012481
# train | epoch = 18, iter = [139|200], loss = 0.122497, loss_box = 0.024452
# train | epoch = 18, iter = [140|200], loss = 0.13101, loss_box = 0.023592
# train | epoch = 18, iter = [141|200], loss = 0.117476, loss_box = 0.012765
# train | epoch = 18, iter = [142|200], loss = 0.127617, loss_box = 0.02428
# train | epoch = 18, iter = [143|200], loss = 0.112326, loss_box = 0.022282
# train | epoch = 18, iter = [144|200], loss = 0.112765, loss_box = 0.013312
# train | epoch = 18, iter = [145|200], loss = 0.110562, loss_box = 0.016535
# train | epoch = 18, iter = [146|200], loss = 0.108911, loss_box = 0.013999
# train | epoch = 18, iter = [147|200], loss = 0.177657, loss_box = 0.020716
# train | epoch = 18, iter = [148|200], loss = 0.16699, loss_box = 0.008651
# train | epoch = 18, iter = [149|200], loss = 0.122735, loss_box = 0.017201
# train | epoch = 18, iter = [150|200], loss = 0.107641, loss_box = 0.016707
# train | epoch = 18, iter = [151|200], loss = 0.084963, loss_box = 0.020342
# train | epoch = 18, iter = [152|200], loss = 0.108822, loss_box = 0.013932
# train | epoch = 18, iter = [153|200], loss = 0.09744, loss_box = 0.017558
# train | epoch = 18, iter = [154|200], loss = 0.100999, loss_box = 0.020435
# train | epoch = 18, iter = [155|200], loss = 0.10813, loss_box = 0.022891
# train | epoch = 18, iter = [156|200], loss = 0.111528, loss_box = 0.020388
# train | epoch = 18, iter = [157|200], loss = 0.115909, loss_box = 0.015927
# train | epoch = 18, iter = [158|200], loss = 0.124582, loss_box = 0.027662
# train | epoch = 18, iter = [159|200], loss = 0.117162, loss_box = 0.011983
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-909ce8f58424> in <cell line: 54>()
#      54 for epoch in range(NUM_EPOCHS):
#      55
# ---> 56   train_loss = train(STEPS_PER_EPOCH, model, optimizer, device, epoch, train_loader, preprocess, BATCH_SIZE)
#      57   val_loss = validate(STEPS_PER_EPOCH, model, optimizer, device, epoch, val_loader, preprocess, BATCH_SIZE)
#      58   lr_scheduler.step()
#
# <ipython-input-13-ad87fdb9e5e3> in train(n_steps, model, optimizer, device, epoch, train_loader, preprocess, batch_size)
#      12     targets = [{k: torch.tensor(v).to(device) for k,v in target.items()} for target in targets]
#      13
# ---> 14     losses = model(images, targets)
#      15     loss = sum(loss for loss in losses.values())
#      16     losses_l.append(loss.item())
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#     102         if isinstance(features, torch.Tensor):
#     103             features = OrderedDict([("0", features)])
# --> 104         proposals, proposal_losses = self.rpn(images, features, targets)
#     105         detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     106         detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/rpn.py in forward(self, images, features, targets)
#     368         # note that we detach the deltas because Faster R-CNN do not backprop through
#     369         # the proposals
# --> 370         proposals = self.box_coder.decode(pred_bbox_deltas.detach(), anchors)
#     371         proposals = proposals.view(num_images, -1, 4)
#     372         boxes, scores = self.filter_proposals(proposals, objectness, images.image_sizes, num_anchors_per_level)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/_utils.py in decode(self, rel_codes, boxes)
#     176         if box_sum > 0:
#     177             rel_codes = rel_codes.reshape(box_sum, -1)
# --> 178         pred_boxes = self.decode_single(rel_codes, concat_boxes)
#     179         if box_sum > 0:
#     180             pred_boxes = pred_boxes.reshape(box_sum, -1, 4)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/_utils.py in decode_single(self, rel_codes, boxes)
#     214
#     215         # Distance from center to box's corner.
# --> 216         c_to_c_h = torch.tensor(0.5, dtype=pred_ctr_y.dtype, device=pred_h.device) * pred_h
#     217         c_to_c_w = torch.tensor(0.5, dtype=pred_ctr_x.dtype, device=pred_w.device) * pred_w
#     218
#
# KeyboardInterrupt:
